# %%
print("My AI Engineer journey starts today 🚀")

# %%
# !pip install langchain openai python-dotenv tiktoken

# %%
import os

print(os.environ.get("OPENAI_API_KEY"))

# %%
from openai import OpenAI
import os

client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

response = client.chat.completions.create(
    model="gpt-4o-mini",   # fast + cheap + very good
    messages=[
        {"role": "user", "content": "Why do Kubernetes pods crash? Explain in simple terms."}
    ],
    temperature=0
)

print(response.choices[0].message.content)

# %%
log = """
CrashLoopBackOff: Back-off restarting failed container

Container failed with error:
OOMKilled: Container ran out of memory.

Last State:
Terminated
Reason: OOMKilled
Exit Code: 137

Node: gke-production-cluster-node-3
Memory Limit: 512Mi
Memory Used: 780Mi
"""

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a senior Kubernetes troubleshooting engineer."},
        {"role": "user", "content": f"Analyze this Kubernetes error log and explain the root cause and solution:\n{log}"}
    ],
    temperature=0
)

print(response.choices[0].message.content)

# %%
"You are a senior Kubernetes troubleshooting engineer."

# %%
Kernel → Restart & Clear Output

# %%
print("API Key Loaded:", bool(os.environ.get("OPENAI_API_KEY")))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print("API Key Loaded:", bool(os.environ.get("OPENAI_API_KEY")))
#
# NameError: name 'os' is not defined
